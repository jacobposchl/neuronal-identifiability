# %% [markdown]
# # RNN Deformation Experiments
#
# Simple notebook to run RNN unit classification experiments.

# %% [markdown]
# ## 1. Clone Repository

# %%
# !git clone https://github.com/YOUR_USERNAME/flowy-neuron-id.git
# %cd flowy-neuron-id

# %% [markdown]
# ## 2. Install Packages

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## 3. Run Integration Test

# %%
# !python scripts/test_integration.py

# %% [markdown]
# ## 4. Multi-Task Comparison
#
# Train RNNs on 4 different tasks (FlipFlop, Cycling, Context, MNIST) and compare unit type distributions.
# Demonstrates task-specific functional specialization.

# %%
# !python scripts/test_rnn.py --task all --architecture vanilla --hidden-size 128 --epochs 2000

# %% [markdown]
# ## 5. Statistical Validation & Advanced Analysis
#
# Comprehensive statistical tests including:
# - Statistical significance (paired t-tests, bootstrap CI, permutation tests)
# - Advanced baseline comparison (TDR, selectivity-based methods)
# - Component ablation study (rotation/contraction/expansion contributions)
#
# Runs on multiple tasks with multiple random seeds for publication-quality rigor.

# %%
# !python scripts/test_comprehensive_analysis.py

# %% [markdown]
# ## 6. Network Pruning Analysis
#
# Test functional importance of unit types by removing specific clusters.
# Demonstrates practical application for network compression and interpretability.

# %%
# !python scripts/test_pruning.py
