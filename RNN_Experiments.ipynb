# %% [markdown]
# # RNN Deformation Experiments
#
# Simple notebook to run RNN unit classification experiments.

# %% [markdown]
# ## 1. Clone Repository

# %%
# !git clone https://github.com/YOUR_USERNAME/flowy-neuron-id.git
# %cd flowy-neuron-id

# %% [markdown]
# ## 2. Install Packages

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## 3. Run Integration Test

# %%
# !python scripts/test_integration.py

# %% [markdown]
# ## 4. Run Single Task Experiment (FlipFlop)

# %%
# !python scripts/test_rnn.py --task flipflop --architecture vanilla --hidden-size 128 --epochs 2000

# %% [markdown]
# ## 5. Run Multi-Task Comparison

# %%
# !python scripts/test_rnn.py --task all --architecture vanilla --hidden-size 128 --epochs 2000

# %% [markdown]
# ## 6. Run Robustness Tests

# %%
# !python scripts/test_rnn_robustness.py
